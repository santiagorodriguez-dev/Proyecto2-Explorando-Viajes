# %%
import pandas as pd
import sys
sys.path.append("../")
from src import soporte_graficos as spg

# %%
df_actividades = pd.read_csv("../data/data_actividades_clean.csv", index_col = 0)
df_hoteles= pd.read_csv("../data/data_hoteles_clean.csv", index_col = 0)
df_vuelos = pd.read_csv("../data/data_sky_scrapper_clean.csv", index_col = 0)

# %% [markdown]
# El gráfico de caja muestra la distribución de los precios de las actividades turísticas agrupados por fecha. Cada caja representa el 50% del central de los datos (entre el primer y tercer cuartil). La línea horizontal dentro de cada caja indica la mediana de los datos.
#
# Los "bigotes" del gráfico se extienden hasta el valor mínimo y máximo que no son considerados valores atípicos, mientras que los puntos fuera de estos límites representan valores atípicos, que son precios significativamente más bajos o altos en comparación con el resto de los datos para esa fecha.
#
# Este gráfico permite observar la variabilidad de los precios de las actividades en diferentes fechas.

# %%
spg.grafico_actividades(df_actividades)

# %% [markdown]
# El gráfico de caja muestra la distribución de los precios de los alojamientos agrupados por fecha. Cada caja representa el 50% del central de los datos (entre el primer y tercer cuartil). La línea horizontal dentro de cada caja indica la mediana de los datos.
#
# Los "bigotes" del gráfico se extienden hasta el valor mínimo y máximo que no son considerados valores atípicos, mientras que los puntos fuera de estos límites representan valores atípicos, que son precios significativamente más bajos o altos en comparación con el resto de los datos para esa fecha.
#
# Este gráfico permite observar la variabilidad de los precios en los alojamientos en diferentes fechas.

# %%
spg.grafico_hoteles(df_hoteles)

# %% [markdown]
# El gráfico de caja muestra la distribución de los precios de los vuelos agrupados por fecha. Cada caja representa el 50% del central de los datos (entre el primer y tercer cuartil). La línea horizontal dentro de cada caja indica la mediana de los datos.
#
# Los "bigotes" del gráfico se extienden hasta el valor mínimo y máximo que no son considerados valores atípicos, mientras que los puntos fuera de estos límites representan valores atípicos, que son precios significativamente más bajos o altos en comparación con el resto de los datos para esa fecha.
#
# Este gráfico permite observar la variabilidad de los precios en los vuelos en diferentes fechas.

# %%
spg.grafico_vuelos(df_vuelos)
